# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 2, 26, 11, 43, 47, 153985)

# %%
print(datetime.datetime.now().year)
print(datetime.datetime.now().month)
print(datetime.datetime.now().day)
print(datetime.datetime.now().hour)
print(datetime.datetime.now().minute)
print(datetime.datetime.now().second)
print(datetime.datetime.now().microsecond)
# Out:
# 2026
# 2
# 26
# 11
# 44
# 48
# 196023

# %%
print(datetime.date.today())
# Out:
# 2026-02-26

# %%
print(datetime.datetime.now().date())
# Out:
# 2026-02-26

# %%
print(datetime.datetime.now().time())
# Out:
# 11:46:09.358846

# %%
print(dir(datetime))
# Out:
# ['MAXYEAR', 'MINYEAR', 'UTC', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'date', 'datetime', 'datetime_CAPI', 'sys', 'time', 'timedelta', 'timezone', 'tzinfo']

# %%
import datetime as dt
print(dt.datetime.now())
# Out:
# 2026-02-26 11:48:27.392421

# %%
from datetime import datetime, time # importamos solo lo que nos interesa de una librería
print(datetime.now())
# Out:
# 2026-02-26 11:50:52.758930

# %%
from datetime import *
print(datetime.now())
# Out:
# 2026-02-26 11:52:01.788585
