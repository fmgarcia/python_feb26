# %% [markdown]
# ## Ejemplos de print

# %%
print("Hola mundo\n"*4)
# Out:
# Hola mundo
# Hola mundo
# Hola mundo
# Hola mundo

# %%
print("Soy Fran")
# Out:
# Soy Fran

# %%
print("Esto es un curso de la eoi")
# Out:
# Esto es un curso de la eoi
