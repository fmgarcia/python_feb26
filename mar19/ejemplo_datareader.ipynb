# %%
import pandas_datareader as pdr
import matplotlib.pyplot as plt

# %%
pdr.__version__
# Out:
# '0.10.0'

# %%
df = pdr.get_data_fred('GS5')
plt.plot(df)
plt.title('Tasa de interés a 5 años')
plt.xlabel('Fecha')
plt.ylabel('Tasa de interés (%)')
plt.show()
