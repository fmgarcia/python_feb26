# %%
fran = ['Fran', 49, 666666666, 'fran@fran.com'] # crea una lista llamada fran que contiene el nombre, la edad, el número de teléfono y el correo electrónico de una persona
print(fran) # imprime la lista fran en la salida
print(fran[0]) # imprime el primer elemento de la lista fran, que es el nombre "Fran"
print(fran[1]) # imprime el segundo elemento de la lista fran, que es laedad 49
print(fran[4]) # imprime el tercer elemento de la lista fran, que es el número de teléfono 666666666
# Out:
# ['Fran', 49, 666666666, 'fran@fran.com']
# Fran
# 49
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 5
#       3 print(fran[0]) # imprime el primer elemento de la lista fran, que es el nombre "Fran"
#       4 print(fran[1]) # imprime el segundo elemento de la lista fran, que es laedad 49
# ----> 5 print(fran[4])
#
# IndexError: list index out of range
