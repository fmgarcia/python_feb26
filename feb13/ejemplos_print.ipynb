# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
print("hola mundo")
print("adios mundo cruel")
# Out:
# hola mundo
# adios mundo cruel

# %%
print("Hola Mundo", end=" ")
print("Adios Mundo")
# Out:
# Hola Mundo Adios Mundo

# %%
print(20)
# Out:
# 20

# %%
print(10+15)
# Out:
# 25

# %%
print("Hola mi número preferido es el " + str(10))
# Out:
# Hola mi número preferido es el 10

# %%
print("hola" + " adios" + " mundo")
# Out:
# hola adios mundo

# %%
print("""El camino hacia las grandes metas rara vez es una línea recta; se parece más a un laberinto donde cada giro nos enseña algo nuevo sobre nuestra propia resistencia.
A veces, la clave no está en correr más rápido que los demás, 
sino en mantener el paso constante cuando el paisaje se vuelve monótono. 
Al final, lo que define el éxito no es solo el destino alcanzado, sino la capacidad de transformar cada obstáculo en una herramienta para seguir avanzando.""")
# Out:
# El camino hacia las grandes metas rara vez es una línea recta; se parece más a un laberinto donde cada giro nos enseña algo nuevo sobre nuestra propia resistencia.
# A veces, la clave no está en correr más rápido que los demás,
# sino en mantener el paso constante cuando el paisaje se vuelve monótono.
# Al final, lo que define el éxito no es solo el destino alcanzado, sino la capacidad de transformar cada obstáculo en una herramienta para seguir avanzando.

# %%
print("Este es mi título")
print("*" * 20)
# Out:
# Este es mi título
# ********************
